# %% [markdown]
# <a href="https://colab.research.google.com/github/BeomJinPNU/202006136/blob/main/2024_03_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **분을 입력받아서 시간과 분을 출력하시오** (.format 메소드 활용)
#
#    *출력* 예)100 -> 1시간 40분

# %%
from os import minor
in_m=int(input("분을 입력하시오"))
hour=in_m//60
min=in_m%60
print("{:d} -> {:d}시간 {:d}분".format(in_m,hour,min))
# Out:
# 분을 입력하시오100
# 100 -> 1시간 40분

# %%
c_t=int(input("섭씨 온도를 입력하시오"))
f_t=c_t * 1.8 + 32
print("섭씨 %d 도는 화씨 %.5f도 입니다."% (c_t,f_t))
# Out:
# 섭씨 온도를 입력하시오100
# 섭씨 100 도는 화씨 212.00000도 입니다.

# %%
PI = 3.14
r=int(input("원의 반지름을 입력하시오"))
circumference = 2 * PI * r
area = PI * (r ** 2)
print("반지름이 {}인 원의 둘레 {} 이고 면적은 {}입니다.".format(r,circumference,area))
# Out:
# 원의 반지름을 입력하시오7
# 반지름이 7인 원의 둘레 43.96 이고 면적은 153.86입니다.
