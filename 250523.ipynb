# %% [markdown]
# <a href="https://colab.research.google.com/github/BeomJinPNU/202006136/blob/main/250523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# %config lnlineBackend.figure_format = 'retina'
# !apt -qq -y install fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,571 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#문제 1: 데이터 파일 열어보기
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Iris.csv')

# %%
#문제 2: 데이터 구경하기
# - 총 몇 개의 붓꽃 데이터가 있나요?
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# - 총 몇 개의 정보(열)가 있나요?
len(df.columns)
## 시험 - 총 데이터 개수와 열 개수 확인
print(len(df))
print(len(df.columns))
# Out:
# 150
# 6

# %%
#문제 3: 각 열의 이름 확인하기
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# 문제 4: 기본 정보 확인하기
# - 비어있는 값(null)이 있나요?
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# - 숫자로 된 열은 몇 개인가요?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# 문제 5: 간단한 계산해보기
# - 꽃받침 길이의 평균은 얼마인가요? 시험 평균 메소드 mean()
SepalLen_mean = df['SepalLengthCm'].mean()
print(SepalLen_mean)
# Out:
# 5.843333333333334

# %%
# - 꽃잎 너비의 최댓값은 얼마인가요? 시험 최대값 메소드 max()
PetalWid_max = df['PetalWidthCm'].max()
print(PetalWid_max)
# Out:
# 2.5

# %%
# 문제 6: 붓꽃 종류별로 개수 세기
# - 각 붓꽃 종류는 몇 개씩 있나요?
# - 세 종류의 개수가 같나요?
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# 문제 7: 특정 조건의 데이터 찾기
# - 꽃잎 길이가 2.0보다 큰 데이터는 몇 개인지 찾아보세요
MorethanPetal = df['PetalLengthCm'] > 2.0
MorethanPetal_data = df[MorethanPetal]
print(MorethanPetal_data)
print(MorethanPetal.sum())
# 시험 더 간단하게
data1 = df[df['PetalLengthCm'] > 2.0]
len(data1)
# Out:
# 100

# %%
# - 꽃받침 너비가 3.5보다 큰 데이터를 찾아보세요
MorethanSepal = df['SepalWidthCm'] > 3.5
MorethanSepal_data = df[MorethanSepal]
print(MorethanSepal_data)
print(MorethanSepal.sum())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 44    45            5.1           3.8            1.9           0.4
# ...

# %%
# 문제 8: 특정 붓꽃 종류만 보기
# - ‘ris-versicolor' 종류만 골라서 평균 꽃잎 길이를 구해보세요
mean_petal_length_by_species = df.groupby('Species')['PetalLengthCm'].mean()
IrisPetalLen_mean = mean_petal_length_by_species['Iris-versicolor']
print(IrisPetalLen_mean)
# - 'Iris-virginica' 종류의 최대 꽃받침 너비를 찾아보세요
max_sepal_width_by_species = df.groupby('Species')['SepalWidthCm'].max()
IrisSepalWid_max = max_sepal_width_by_species['Iris-virginica']
print(IrisSepalWid_max)
# Out:
# 4.26
# 3.8

# %%
# 문제 9: 첫 번째 그래프 그리기
# - 꽃잎 길이의 히스토그램도 그려보세요
# - 어떤 구간에 데이터가 가장 많은지 관찰해보세요
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.hist(df['PetalLengthCm'])
plt.xlabel('꽃잎 길이 (cm)')  # x축 라벨 추가
plt.ylabel('빈도') # y축 라벨 추가
plt.title('꽃잎 길이 분포 히스토그램') # 제목 추가
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
# 문제 10: 산점도 그리기
# - 꽃잎 길이와 너비의 산점도도 그려보세요
# - 길이가 길수록 너비도 넓어지는지 관찰해보세요
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'])
plt.xlabel('꽃잎 길이 (cm)')
plt.ylabel('꽃잎 너비 (cm)')
plt.title('꽃잎 길이와 너비 산점도')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 문제 11: 붓꽃 종류별로 다른 색깔로 산점도 그리기
# - 어떤 종류가 가장 구별되어 보이나요?
# - 서로 겹치는 종류가 있나요?
import seaborn as sns
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df, x='PetalLengthCm', y='PetalWidthCm', hue='Species', style='Species', s=100)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
# 문제 12: 종류별 평균 비교하기
# 어떤 종류가 꽃받침이 가장 긴가요? sepallength
# 어떤 종류가 꽃잎이 가장 넓은가요? petalwidth
# 결과를 표로 정리
fic_mean_stats = df.groupby('Species')[['SepalLengthCm', 'PetalWidthCm']].mean()
fic_mean_stats
# Out:
#                  SepalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         0.244
# Iris-versicolor          5.936         1.326
# Iris-virginica           6.588         2.026

# %%
# 문제 13: 막대그래프로 평균 비교하기
# 꽃잎 길이의 평균을 막대그래프로 그리기
# 가장 큰 차이를 보이는 측정값 찾기
species_PetalLengthCm_mean_stats = df.groupby('Species')['PetalLengthCm'].mean()
plt.figure(figsize=(8, 6))
species_PetalLengthCm_mean_stats.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
# 문제 14: 박스플롯
# subplot을 사용해 4개의 그래프를 한 번에 표현
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Distribution of Iris Features by Species', fontsize = 16)
sns.boxplot(ax=axes[0, 0], data=df, x='Species', y='SepalLengthCm')
sns.boxplot(ax=axes[0, 1], data=df, x='Species', y='SepalWidthCm')
sns.boxplot(ax=axes[1, 0], data=df, x='Species', y='PetalLengthCm')
sns.boxplot(ax=axes[1, 1], data=df, x='Species', y='PetalWidthCm')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
iris_df_area = df.copy()
# 꽃받침 면적 계산
iris_df_area['SepalArea'] = iris_df_area['SepalLengthCm'] * iris_df_area['SepalWidthCm']
# 꽃잎 면적 계산
iris_df_area['PetalArea'] = iris_df_area['PetalLengthCm'] * iris_df_area['PetalWidthCm']

# %%
iris_df_area
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  SepalArea  PetalArea
# 0       Iris-setosa      17.85       0.28
# 1       Iris-setosa      14.70       0.28
# ...

# %%
# 문제 16: 데이터 필터링
# 꽃받침 너비가 3.0 이상이고 꽃잎 너비가 1.5 이상인 데이터를 찾아보세요
# 그 데이터들은 주로 어떤 종류인가요?
data3 = df[(df['SepalWidthCm'] >= 3.0) & (df['PetalWidthCm'] >= 1.5)]
# 다시 종 별로 밸류카운트
filtered_species_counts = data3['Species'].value_counts()
print(filtered_species_counts)
# Out:
# Species
# Iris-virginica     29
# Iris-versicolor    10
# Name: count, dtype: int64

# %%
# 순위 매기기
# top 10에 가장 많이 포함된 종류는?
top_10_sepal_length = df.sort_values(by='SepalLengthCm', ascending=False).head(10)
print(top_10_sepal_length)
# top 10에 가장 적게 포함된 종류는?
lowest_10_sepal_length = df.sort_values(by='SepalLengthCm', ascending=False).tail(10)
print(lowest_10_sepal_length)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 105  106            7.6           3.0            6.6           2.1
# 130  131            7.4           2.8            6.1           1.9
# 107  108            7.3           2.9            6.3           1.8
# 109  110            7.2           3.6            6.1           2.5
# 129  130            7.2           3.0            5.8           1.6
#
#             Species
# 131  Iris-virginica
# 122  Iris-virginica
# 118  Iris-virginica
# 117  Iris-virginica
# 135  Iris-virginica
# 105  Iris-virginica
# 130  Iris-virginica
# 107  Iris-virginica
# 109  Iris-virginica
# ...
